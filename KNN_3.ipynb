# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset["Purchased"].value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %%
indep=dataset[["Age","EstimatedSalary","Gender_Male"]]
dep=dataset["Purchased"]

# %%
indep.shape
# Out:
# (400, 3)

# %%
dep
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Create a KNeighborsClassifier object
knn = KNeighborsClassifier()

# Create a dictionary of parameter names and values
param_grid = {
  'n_neighbors': [3, 5, 7],
  'weights': ['uniform', 'distance'],
  'metric': ['euclidean', 'manhattan', 'cosine']
}

# Create a GridSearchCV object
grid = GridSearchCV(knn, param_grid, refit = True, verbose = 3,n_jobs=-1)

# Fit the model to the data
grid.fit(X_train, y_train)

# Get the best model
best_model = grid.best_estimator_
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.002929      0.000431         0.016608        0.014462    euclidean
# 1        0.002438      0.000445         0.002484        0.000532    euclidean
# 2        0.002771      0.000454         0.008175        0.000342    euclidean
# 3        0.002358      0.000210         0.002620        0.000421    euclidean
# 4        0.002845      0.000919         0.008460        0.001750    euclidean
# 5        0.002307      0.000045         0.002413        0.000032    euclidean
# 6        0.003410      0.002318         0.007842        0.001848    manhattan
# 7        0.002331      0.000130         0.002428        0.000021    manhattan
# 8        0.002291      0.000030         0.007297        0.000684    manhattan
# 9        0.002454      0.000363         0.002424        0.000045    manhattan
# 10       0.002259      0.000022         0.006937        0.000071    manhattan
# 11       0.002117      0.000339         0.002176        0.000314    manhattan
# 12       0.002124      0.000073         0.008578        0.002393       cosine
# 13       0.002094      0.000044         0.002872        0.000063       cosine
# 14       0.002338      0.000347         0.007572        0.000413       cosine
# 15       0.002234      0.000059         0.003191        0.000420       cosine
# 16       0.002619      0.000506         0.008012        0.000796       cosine
# 17       0.002200      0.000130         0.002895        0.000093       cosine
#
#    param_n_neighbors param_weights  \
# 0                  3       uniform
# 1                  3      distance
# 2                  5       uniform
# 3                  5      distance
# 4                  7       uniform
# 5                  7      distance
# 6                  3       uniform
# 7                  3      distance
# 8                  5       uniform
# 9                  5      distance
# 10                 7       uniform
# 11                 7      distance
# 12                 3       uniform
# 13                 3      distance
# 14                 5       uniform
# 15                 5      distance
# 16                 7       uniform
# 17                 7      distance
#
#                                                params  split0_test_score  \
# 0   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.833333
# 1   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.851852
# 2   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...           0.759259
# 3   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...           0.833333
# 4   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.759259
# 5   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.833333
# 6   {'metric': 'manhattan', 'n_neighbors': 3, 'wei...           0.833333
# 7   {'metric': 'manhattan', 'n_neighbors': 3, 'wei...           0.851852
# 8   {'metric': 'manhattan', 'n_neighbors': 5, 'wei...           0.759259
# 9   {'metric': 'manhattan', 'n_neighbors': 5, 'wei...           0.833333
# 10  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...           0.759259
# 11  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...           0.833333
# 12  {'metric': 'cosine', 'n_neighbors': 3, 'weight...           0.537037
# 13  {'metric': 'cosine', 'n_neighbors': 3, 'weight...           0.518519
# 14  {'metric': 'cosine', 'n_neighbors': 5, 'weight...           0.574074
# 15  {'metric': 'cosine', 'n_neighbors': 5, 'weight...           0.481481
# 16  {'metric': 'cosine', 'n_neighbors': 7, 'weight...           0.518519
# 17  {'metric': 'cosine', 'n_neighbors': 7, 'weight...           0.481481
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.830189           0.754717           0.792453
# 1            0.792453           0.735849           0.792453
# 2            0.754717           0.716981           0.849057
# 3            0.773585           0.716981           0.811321
# 4            0.811321           0.754717           0.811321
# 5            0.792453           0.716981           0.811321
# 6            0.830189           0.754717           0.792453
# 7            0.811321           0.735849           0.792453
# 8            0.754717           0.716981           0.849057
# 9            0.773585           0.716981           0.811321
# 10           0.811321           0.754717           0.811321
# 11           0.792453           0.716981           0.811321
# 12           0.622642           0.584906           0.622642
# 13           0.603774           0.566038           0.716981
# 14           0.622642           0.679245           0.660377
# 15           0.622642           0.622642           0.716981
# 16           0.622642           0.735849           0.622642
# 17           0.584906           0.622642           0.716981
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.754717         0.793082        0.034471                1
# 1            0.735849         0.781691        0.043260                4
# 2            0.792453         0.774493        0.044301                7
# 3            0.735849         0.774214        0.043863                9
# 4            0.735849         0.774493        0.031078                5
# 5            0.716981         0.774214        0.048489               11
# 6            0.754717         0.793082        0.034471                1
# 7            0.735849         0.785465        0.044829                3
# 8            0.792453         0.774493        0.044301                7
# 9            0.735849         0.774214        0.043863                9
# 10           0.735849         0.774493        0.031078                5
# 11           0.716981         0.774214        0.048489               11
# 12           0.716981         0.616841        0.059134               18
# 13           0.735849         0.628232        0.084807               16
# 14           0.698113         0.646890        0.044142               13
# 15           0.754717         0.639693        0.094675               14
# 16           0.641509         0.628232        0.069076               16
# 17           0.735849         0.628372        0.092630               15
